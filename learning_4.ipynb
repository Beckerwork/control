# %%
import sys
import os

# %matplotlib widget

sys.path.append(os.path.abspath("src"))
from regression.regression_choice import regression_choice_2
from IPython.display import display, HTML

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; position: relative; padding: 24px 24px 20px 24px; margin-top: 25px; border: 4px solid #3c763d;">
#   <span style="position: absolute; top: -28px; left: 16px; background-color: #3c763d; color: white; border-radius: 50%; width: 56px; height: 56px; display: inline-flex; align-items: center; justify-content: center; font-size: 28px;">
#     <i class="fa fa-book"></i>
#   </span>
#   <h2>Das richtige Modell</h2>
#
#   <img src="src/images/chart.jpg" style="float: right; margin-left: 16px; margin-bottom: 8px; max-width: 220px; border-radius: 6px;">
#
#   <p>Wir betrachten ein weiteres Beispiel. Unten sind Datenpunkte abgebildet, um zu zeigen, wie weit eine Person in einer bestimmten Zeit läuft. Du hast gesehen, dass es verschiedene Arten von Zusammenhängen gibt. Welches Modell passt hier?</p>
#
#   <div style="clear: both;"></div>
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 10px; position: relative; padding: 24px 24px 20px 24px; margin-top: 25px; border: 4px solid #31708f;">
#   <span style="position: absolute; top: -28px; left: 16px; background-color: #31708f; color: white; border-radius: 50%; width: 56px; height: 56px; display: inline-flex; align-items: center; justify-content: center; font-size: 28px;">
#     <i class="fa fa-pencil"></i>
#   </span>
#   <h3>Aufgabe 4 – Modelle vergleichen</h3>
#   <p>Schaue dir die Datenpunkte an. Klicke auf 'Zeige Modell' und vergleiche die Fehlerwerte. Welches Modell passt besser zu den Datenpunkten?</p>
# </div>

# %%
regression_choice_2()
# Out:
# Checkbox(value=False, description='Zeige lineares Modell', indent=False)
# Checkbox(value=False, description='Zeige quadratisches Modell', indent=False)
# Canvas(header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Bac…

# %%
with open("src/widgets/model_selection.html", "r") as f: display(HTML(f.read()))
# Out:
# <div class="alert alert-info" style="border-radius: 10px; position: relative; padding: 24px 24px 20px 24px; margin-top: 25px; border: 4px solid #31708f; max-width: 500px; margin-left: auto; margin-right: auto;">
#   <span style="position: absolute; top: -28px; left: 16px; background-color: #31708f; color: white; border-radius: 50%; width: 56px; height: 56px; display: inline-flex; align-items: center; justify-content: center; font-size: 28px;">
#     <i class="fa fa-lock"></i>
#   </span>
#   <div style="text-align:center; margin-bottom:16px;">
#     <h3 style="color:#31708f; margin:0 0 6px 0;">📊 Modellauswahl</h3>
#     <p style="margin:0; color:#31708f; font-size:14px;">
#       Passt das lineare oder das quadratische Modell besser?
#     </p>
#   </div>
#   <hr style="border:none; border-top:1px solid #31708f; opacity:0.3; margin-bottom:16px;">
#
#   <div style="display:flex; justify-content:center; gap:12px; margin-bottom:16px;">
# ...
